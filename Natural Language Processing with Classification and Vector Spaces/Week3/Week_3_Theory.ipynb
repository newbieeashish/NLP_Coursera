# %%
from IPython.display import Image

# %%
Image("word_by_doc.JPG")

# %%
Image("Eulidean_distance.JPG")

# %%
Image("ED_vs_Cosine.JPG")

# %%
Image("cosine_python.JPG")

# %%
Image('manipulating_words.JPG')

# %%
Image("pca.JPG")

# %%
Image('pca_algo.JPG')
